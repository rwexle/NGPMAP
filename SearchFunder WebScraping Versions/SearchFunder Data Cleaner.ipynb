# %%
import pandas as pd
import csv
import numpy as np
import matplotlib as plt
from unicodedata import normalize

# %%
df = pd.read_csv("searchfund_allv3.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1949 non-null   int64
#  1   name              1948 non-null   object
#  2   type              1949 non-null   object
#  3   formed            1715 non-null   float64
#  4   location_x        1949 non-null   object
#  5   stage             1949 non-null   object
#  6   company           614 non-null    object
#  7   acquired          625 non-null    float64
#  8   searchfund_index  1949 non-null   int64
#  9   searchWebsite     1382 non-null   object
#  10  companyWebsite    548 non-null    object
#  11  industry          597 non-null    object
#  12  location_y        599 non-null    object
#  13  searchers         1949 non-null   object
#  14  investors         1949 non-null   object
#  15  associates        1949 non-null   object
# ...

# %%
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                     Nova Capital
# 1              1  Galena Corp  Harvard University - Harvard Busi...
# 2              2                                     Hanover West
# 3              3  David Dodson - 1st Fund  Stanford University -...
# 4              4                   Balkin Corp  Stanford University
# ...          ...                                                ...
# 1944        1944                 Golden Eagle Capital Partners, LLC
# 1945        1945                          Infini Capital Partners
# 1946        1946                                 Heritage Holding
# 1947        1947                  Arbor Lane Capital Partners LLC
# 1948        1948                                 West 88 Partners
#
#                 type      formed                          location_x  \
# 0     Single Sponsor  19840101.0           Boston, MA, United States
# ...

# %%
#turing the formed and acquired fields into datetime format
df['formed'] = pd.to_datetime(df['formed'].astype(str), format = '%Y%m%d.0')
df['acquired'] = pd.to_datetime(df['acquired'].astype(str), format = '%Y%m%d.0')

# %%
#find the amount of days between forming fund and acquisition
df['search time'] = (df['acquired'] - df['formed']).dt.days

# %%
df['searchers'] = df['searchers'].replace(['\xa0'],[' '])

# %%
df['searchers'][0][0]
# Out:
# '['

# %%
#convert from list to string
df['searchers'] = df['searchers'].apply(lambda x: x[1:-1])
df['investors'] = df['investors'].apply(lambda x: x[1:-1])
df['associates'] = df['associates'].apply(lambda x: x[1:-1])

# %%
type(df['searchers'][0])
# Out:
# str

# %%
df['searchers']
# Out:
# 0                                   'Jim\xa0Southern'
# 1             'Jamie\xa0Turner ', 'Kirk\xa0Riedinger'
# 2         'Paul\xa0Centenari ', 'Peter\xa0Centenari '
# 3                                   'David\xa0Dodson'
# 4                                   'Jeff\xa0Stevens'
#                             ...
# 1944
# 1945    'Alberto\xa0Betancourt', 'Rafael\xa0Zambrano'
# 1946                                  'Tim\xa0Rooney'
# 1947                                 'Joanne\xa0Poon'
# 1948            'Ameel\xa0Velji', 'Matthew\xa0Hanson'
# Name: searchers, Length: 1949, dtype: object

# %%
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                     Nova Capital
# 1              1  Galena Corp  Harvard University - Harvard Busi...
# 2              2                                     Hanover West
# 3              3  David Dodson - 1st Fund  Stanford University -...
# 4              4                   Balkin Corp  Stanford University
# ...          ...                                                ...
# 1944        1944                 Golden Eagle Capital Partners, LLC
# 1945        1945                          Infini Capital Partners
# 1946        1946                                 Heritage Holding
# 1947        1947                  Arbor Lane Capital Partners LLC
# 1948        1948                                 West 88 Partners
#
#                 type     formed                          location_x     stage  \
# 0     Single Sponsor 1984-01-01           Boston, MA, United States  Acquired
# ...

# %%
#df['searcherstring'] = df["searcherstring"].apply(eval)
#df['investors'] = df['investors'].apply(eval)
#df['associates'] = df['associates'].apply(eval)

# %%
df['searcherstring'] = df['searcherstring'].replace(['\\xa0'], ' ')

# %%
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                     Nova Capital
# 1              1  Galena Corp  Harvard University - Harvard Busi...
# 2              2                                     Hanover West
# 3              3  David Dodson - 1st Fund  Stanford University -...
# 4              4                   Balkin Corp  Stanford University
# ...          ...                                                ...
# 1944        1944                 Golden Eagle Capital Partners, LLC
# 1945        1945                          Infini Capital Partners
# 1946        1946                                 Heritage Holding
# 1947        1947                  Arbor Lane Capital Partners LLC
# 1948        1948                                 West 88 Partners
#
#                 type     formed                          location_x     stage  \
# 0     Single Sponsor 1984-01-01           Boston, MA, United States  Acquired
# ...

# %%
#def clean_alt_list(list_):
 #   list_ = list_.replace(', ', '","')
  #  list_ = list_.replace('[', '["')
   # list_ = list_.replace(']', '"]')
    #return list_

# %%
#df['searchers'] = df["searchers"].apply(clean_alt_list)

# %%
df.to_csv("TestDf2.csv", index = False)

# %%
df["searchers"][0] = df['searchers'][0].replace("\xa0", " ", regex =True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\PATRIC~1\AppData\Local\Temp/ipykernel_7744/1284622233.py in <module>
# ----> 1 df["searchers"][0] = df['searchers'][0].replace("\xa0", " ", regex =True)
#
# TypeError: str.replace() takes no keyword arguments

# %%
df['searchers'][0]
# Out:
# "['Jim\\xa0Southern']"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1949 non-null   int64
#  1   name              1948 non-null   object
#  2   type              1949 non-null   object
#  3   formed            1949 non-null   object
#  4   location_x        1949 non-null   object
#  5   stage             1949 non-null   object
#  6   company           614 non-null    object
#  7   acquired          1949 non-null   object
#  8   searchfund_index  1949 non-null   int64
#  9   searchWebsite     1382 non-null   object
#  10  companyWebsite    548 non-null    object
#  11  industry          597 non-null    object
#  12  location_y        599 non-null    object
#  13  searchers         1949 non-null   object
#  14  investors         1949 non-null   object
#  15  associates        1949 non-null   object
# ...

# %%
df["formed"][0]
# Out:
# str

# %%
df['formed'] = pd.to_datetime(df['formed'], format = "%y/%m/%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\patrick moore\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# c:\users\patrick moore\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\PATRIC~1\AppData\Local\Temp/ipykernel_7744/3361446733.py in <module>
# ...
